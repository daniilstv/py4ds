# %%
import numpy as np
import math
from matplotlib import pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'

# %% [markdown]
# 1. Задание
# Даны два вектора в трехмерном пространстве: (10,10,10) и (0,0,-10)
# Найдите их сумму. (на листочке)
# Напишите код на Python, реализующий расчет длины вектора, заданного его координатами. (в программе)

# %%
# 1.
# (10+0, 10+0, 10 - 10)
# Сумма векторов (10, 10, 0)

# %%
a = np.array([10,10,10])
b = np.array([0,0,-10])
print("Результирующий вектор равен:",a+b)
# Out:
# Результирующий вектор равен: [10 10  0]

# %% [markdown]
# 2. Задание (на листочке)
# Почему прямые не кажутся перпендикулярными? (см.ролик)

# %% [markdown]
# #2. Наклон прямой определяется коэффициентом при Х. Пересечение оси y - свободным коэффициентом.
# Прямые в примере не кажутся перпендикулярными, т.к. масштаб координатных осей не совпадает. Тем не менее, прямые перпендикулярны.

# %%
x = np.linspace(-5,5,21)
y = 3*x+1
y2 = (-1/3)*x+1
plt.plot(x, y)
plt.plot(x, y2)

plt.xlabel('x')
plt.ylabel('y')

# Выравнивание масштаба осей 
plt.axes().set_aspect(1)

plt.show()

# %% [markdown]
# 3. Задание (в программе)
# Напишите код на Python, реализующий построение графиков:
# окружности,
# эллипса,
# гиперболы.

# %%
# http://inp.nsk.su/~grozin/python/python6.html
# https://stackoverflow.com/questions/7965743/how-can-i-set-the-aspect-ratio-in-matplotlib
# https://toster.ru/q/220495

# %%
# 3.1 график окружности
# (x – x0)**2 + (y – y0)**2 = r2
# (х - 0)**2 + (у - 0)**2 = 16
# x**2 + y**2 = 16

x0 = 0
y0 = 0
r = 4

x = []
y = []

rng = np.linspace(-r, r, 101)

for i in range(len(rng)):
    x_tmp = rng[i]
    x.append(x_tmp)
    y_tmp = math.sqrt(r**2 - x_tmp**2)
    y.append(y_tmp)

for i in range(len(rng)):
    x_tmp = rng[~i]
    x.append(x_tmp)
    y_tmp = -1*math.sqrt(r**2 - x_tmp**2)
    y.append(y_tmp)
    
plt.plot(x, y)
plt.axes().set_aspect(1)
plt.show()

# %%
# подсмотренный пример
t = np.arange(0,2*np.pi,0.01)
r=4
plt.plot(r*np.sin(t),r*np.cos(t),lw=3)
plt.axis('equal')
plt.show()

# %%
# 3.2 график эллипса
# x**2/a**2 + y**2/b**2 = 1 , a > b
# c = sqrt(a**2-b**2)

a = 16
b = 9
c = math.sqrt(a**2-b**2)

x = []
y = []

rng_x = np.linspace(-1*math.sqrt(a), math.sqrt(a), 101)

for i in range(len(rng_x)):
    x_tmp = rng_x[i]
    x.append(x_tmp)
    y_tmp = math.sqrt(b/a*(a-x_tmp**2)) 
    y.append(y_tmp)

for i in range(len(rng_x)):
    x_tmp = rng_x[~i]
    x.append(x_tmp)
    y_tmp = -1*math.sqrt(b/a*(a-x_tmp**2)) 
    y.append(y_tmp)
    
plt.plot(x, y)
plt.axes().set_aspect(1)
plt.show()

# %%
# 3.3 График гиперболы

# %%
def drow_plot(f, n=100, a = 0): # функция отрисовки графиков y=f(x) по функции
    
    xmin = -1 * n
    xmax = n + 1
    dx = 1
    x = np.around(np.arange(xmin, xmax, dx) , decimals=4)

    y = eval(f)
    
    if a == 0:
        aspect = 'auto'
    else:
        aspect = 1

    plt.plot(x, y)
    plt.axes().set_aspect(aspect)
    plt.show()

# %%
# тест функции
drow_plot("math.pi*(x**2)",20)

# %%
# 3.3 График гиперболы
drow_plot("1/x",20)
# ошибка деления на ноль, т.к. x!=0
# Out:
# /Users/daniil/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in true_divide
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# 4. Задание (на листочке)
# 1) Пусть задана плоскость:
#   A*x + B*y + C*z + D = 0
# Напишите уравнение плоскости, параллельной данной и проходящей через начало координат.
#
#
# 2)  Пусть задана плоскость: A1x + B1y + C1z + D1 = 0
# и прямая:
# (x-x1)/(x2-x1)=(y-y1)/(y2-y1)=(z-z1)/(z2-z1)
# Как узнать, принадлежит прямая плоскости или нет?

# %%
# 4.1 Непересекающаяся плоскость имеет следующую формулу:
n*A*x + n*B*y + n*C*z + m = 0
# т.е. переменные кратны - умножаются на одинаковый коэффициент. Свободный член произвольный.

# %%
# 4.2 Прямая принадлежит плоскости, если две точки прямой лежат на плоскости.
в уравнении (x-x1)/(x2-x1)=(y-y1)/(y2-y1)=(z-z1)/(z2-z1)
точки x1,x2,y1,y2,z1,z2 должны принадлежать плоскости A1x + B1y + C1z + D1 = 0
Т.е. если подставить их значения, то должно соблюдаться равенство

A1x1 + B1y1 + C1z1 + D1 = 0
A1x2 + B1y2 + C1z2 + D1 = 0

# %%
5. Задание (в программе)
Нарисуйте трехмерный график двух параллельных плоскостей.
Нарисуйте трехмерный график двух любых поверхностей второго порядка.

# %%
5.1

# %%
yy, zz = np.meshgrid(range(2), range(2))
xx = yy*0

x1x1 = yy *0 + 2

ax = plt.subplot(projection='3d')
ax.plot_surface(xx, yy, zz)
ax.plot_surface(x1x1, yy, zz)
plt.show()

# %%
# 5.2

# %%
# взято из http://itrobo.ru/programmirovanie/python/grafiki-funkcii-i-poverhnostei-v-python-.html

# уравнение поверхности
f = lambda x, y: (x ** 2)/5 - (y ** 2)/2

# создаём полотно для рисунка
fig = plt.figure(figsize = (5, 5))

# создаём рисунок пространства с поверхностью
ax = fig.add_subplot(1, 1, 1, projection = '3d')

# размечаем границы осей для аргументов
xval = np.linspace(-4, 4, 100)
yval = np.linspace(-4, 4, 100)

# создаём массив с xval столбцами и yval строками
# - в этом массиве будут храниться значения z
x, y = np.meshgrid(xval, yval)

# приравниваем z к функции от x и y 
z = f(x, y)

# создаём поверхность
surf = ax.plot_surface(x, y, z, rstride = 10, cstride = 10)

# %%
# взято из http://itrobo.ru/programmirovanie/python/grafiki-funkcii-i-poverhnostei-v-python-.html

# уравнение поверхности
f = lambda x, y: (x ** 2)/5 + (y ** 2)/2

# создаём полотно для рисунка
fig = plt.figure(figsize = (5, 5))

# создаём рисунок пространства с поверхностью
ax = fig.add_subplot(1, 1, 1, projection = '3d')

# размечаем границы осей для аргументов
xval = np.linspace(-4, 4, 100)
yval = np.linspace(-4, 4, 100)

# создаём массив с xval столбцами и yval строками
# - в этом массиве будут храниться значения z
x, y = np.meshgrid(xval, yval)

# приравниваем z к функции от x и y 
z = f(x, y)

# создаём поверхность
surf = ax.plot_surface(x, y, z, rstride = 10, cstride = 10)

# %%
from mpl_toolkits.mplot3d import axes3d
ax = axes3d.Axes3D(plt.figure())

i = np.arange(-1, 1, 0.01)
X, Y = np.meshgrid(i, i)
Z = X**2-Y**2

ax.plot_wireframe(X, Y, Z, rstride=10, cstride=10)
plt.show()

# %%
from mpl_toolkits.mplot3d import axes3d
ax = axes3d.Axes3D(plt.figure())

i = np.arange(-1, 1, 0.01)
X, Y = np.meshgrid(i, i)
Z = X**2+Y**2

ax.plot_wireframe(X, Y, Z, rstride=10, cstride=10)
plt.show()

# %%
fig = plt.figure(figsize=plt.figaspect(1))  # Square figure
ax = fig.add_subplot(111, projection='3d')

coefs = (1, 2, 2)  # Coefficients in a0/c x**2 + a1/c y**2 + a2/c z**2 = 1 
# Radii corresponding to the coefficients:
rx, ry, rz = 1/np.sqrt(coefs)

# Set of all spherical angles:
u = np.linspace(0, 2 * np.pi, 100)
v = np.linspace(0, np.pi, 100)

# Cartesian coordinates that correspond to the spherical angles:
# (this is the equation of an ellipsoid):
x = rx * np.outer(np.cos(u), np.sin(v))
y = ry * np.outer(np.sin(u), np.sin(v))
z = rz * np.outer(np.ones_like(u), np.cos(v))

# Plot:
ax.plot_surface(x, y, z,  rstride=4, cstride=4, color='b')

# Adjustment of the axes, so that they all have the same span:
max_radius = max(rx, ry, rz)
for axis in 'xyz':
    getattr(ax, 'set_{}lim'.format(axis))((-max_radius, max_radius))

plt.show()

# %%
# Эллипсоид, гиперболоиды построить не удалось

from mpl_toolkits.mplot3d import axes3d
ax = axes3d.Axes3D(plt.figure())

i = np.arange(-1, 1, 0.01)
X, Y = np.meshgrid(i, i)
Z = math.sqrt((X**2+Y**2) )

ax.plot_wireframe(X, Y, Z, rstride=10, cstride=10)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-377-2f92ea94f166> in <module>
#       7 X, Y = np.meshgrid(i, i)
#       8
# ----> 9 Z = math.sqrt((X**2+Y**2) )
#      10
#      11 ax.plot_wireframe(X, Y, Z, rstride=10, cstride=10)
#
# TypeError: only size-1 arrays can be converted to Python scalars

# %% [markdown]
# ##### Тема “Графики на плоскости”

# %%
Чему равны синус, косинус, тангенс перечисленных углов?
Запишите значения в таблицу:

# %% [markdown]
# ![Tablica-tangensov.gif](attachment:Tablica-tangensov.gif)

# %%
1. Задание (в программе)
Нарисуйте график функции:
y(x) = k∙cos(x – a) + b
для некоторых (2-3 различных) значений параметров k, a, b

# %%
# 1. 
k = 1
a = 0.5
b = 1

def cos(k,a,b):
    x = np.linspace(-10, 10, 100)
    plt.plot(x, k*np.cos(x-a)+b)
    
cos(k,a,b)
cos(2,3,5)
cos(-2,-3,-2)

# %%
2. Задание 
Докажите, что при ортогональном преобразовании сохраняется расстояние между точками.

# %%
# 2. Ортогональное преобразование - это линейный перенос плюс поворот.
Расстояние между точками сохраняется при линейном переносе.
Расстояние между точками сохраняется при повороте.
=> Расстояние между точками сохранится при ортагональном преобразовании.
Ортогональное преобразование всегда является аффинным.

# %%
3. Задание (в программе)
Напишите код, который будет переводить полярные координаты в декартовы.
Напишите код, который будет рисовать график окружности в полярных координатах.
Напишите код, который будет рисовать график отрезка прямой линии в полярных координатах.

# %%
# 3.1

def pol2cart(rho, phi):
    x = rho * np.cos(phi)
    y = rho * np.sin(phi)
    return x, y
pol2cart(1, 90)
# Out:
# (-0.4480736161291701, 0.8939966636005579)

# %%
# 3.2
fig = plt.figure(figsize=(10, 10))

#phi = np.arange(2*np.pi,0.01)
phi =np.linspace(0, 1, 360)*np.pi 
rho = np.sin(phi)
 
ax1 = fig.add_subplot(232, projection='polar')
ax1.plot(phi,rho)
ax1.grid(True)
 
plt.show()

# %%
# 3.2
theta = np.arange(0., 2., 1./180.)*np.pi    # 360 точек

#plt.polar(3*theta, theta/5)         # спираль
#plt.polar(theta, np.cos(4*theta))   # уравнение розы
plt.polar(theta, [1.4]*len(theta))  # окружность

plt.show()

# %%
# 3.3
fig = plt.figure(figsize=(10, 10))

phi = [1,1]
#phi =np.linspace(0, 1, 360)*np.pi 
rho = [0,4]
 
ax1 = fig.add_subplot(232, projection='polar')
ax1.plot(phi,rho, color = "red")
ax1.grid(True)
 
plt.show()

# %%
4. Задание (в программе)
Решите систему уравнений:
y = x2 – 1
exp(x) + x∙(1 – y) = 1


Решите систему уравнений и неравенств:
y = x2 – 1
exp(x) + x∙(1 – y) > 1

# %%
# 4.1

# %%
# 4.2
